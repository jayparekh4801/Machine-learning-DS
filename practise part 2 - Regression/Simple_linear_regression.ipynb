# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # importing dataset

# %%
dataset = pd.read_csv("/Users/jayparekh/Documents/machine_learning_dataScience/Machine Learning A-Z (Codes and Datasets)/Part 2 - Regression/Section 4 - Simple Linear Regression/Python/Salary_Data.csv")
independent = dataset.iloc[ : ,  : -1].values
dependent = dataset.iloc[ : , -1 : ].values

# %% [markdown]
# # Handeling Null Values

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy="mean")
imputer.fit(independent)
independent = imputer.transform(independent)

# %% [markdown]
# # Splitting Dataset Into Trainin_Set and Test_set

# %%
from sklearn.model_selection import train_test_split
independent_train, independent_test, dependent_train, dependent_test = train_test_split(independent, dependent, test_size=0.2, random_state=5)

# %% [markdown]
# # Building The Simple Regression Model For Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression();
regressor.fit(independent_train, dependent_train)
# Out:
# LinearRegression()

# %% [markdown]
# # predicting the Idependent Test from Regression Model

# %%
dependent_prediction = regressor.predict(independent_test)

# %%
dependent_prediction
# Out:
# array([[ 63822.10276786],
#        [125176.91866803],
#        [103466.75304182],
#        [111018.11499876],
#        [ 81756.5874156 ],
#        [ 62878.18252324]])

# %%
dependent_test
# Out:
# array([[ 55794.],
#        [121872.],
#        [113812.],
#        [105582.],
#        [ 81363.],
#        [ 63218.]])

# %% [markdown]
# # Visualising Training Set Values

# %%
plt.scatter(independent_train, dependent_train, color = "red")
plt.plot(independent_train, regressor.predict(independent_train), color = "blue")
plt.title("Salary vs Experience(Training Set)")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # Visualising Test Set Values

# %%
plt.scatter(independent_test, dependent_test, color = "red")
plt.plot(independent_test, dependent_prediction)
plt.title("Salary vs Experience(Test Set)")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(independent_test, dependent_test, color = "red")
plt.plot(independent_test, dependent_test, color = "orange", label = "original")
plt.plot(independent_test, dependent_prediction, color = "blue", label = "prediction")

# %% [markdown]
# # Salary Prediction At Particular Value

# %%
regressor.predict([[12]])
# Out:
# array([[139335.7223373]])

# %% [markdown]
# here 12 is experience years

# %% [markdown]
# Get Values Of Coefficient Of Simple Linear Regreesion Model.  Ex. y = ax + b
# where a is coefficient and b is y-axis intercept

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [[9439.20244618]]
# [26065.29298314]

# %% [markdown]
# So the simple linear regression equation is y = 9312.57 * x + 26780.09
