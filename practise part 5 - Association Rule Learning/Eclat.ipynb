# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
dataset = pd.read_csv("/Users/jayparekh/Documents/machine_learning_dataScience/Machine Learning A-Z (Codes and Datasets)/Part 5 - Association Rule Learning/Section 28 - Apriori/Python/Market_Basket_Optimisation.csv", header = None)
transactions = []
for i in dataset.index :
    transactions.append([str(item) for item in dataset.iloc[i, : ]])

# %% [markdown]
# # Making Eclat Model

# %%
from apyori import apriori
sets = apriori(transactions = transactions, min_support = 0.0046, min_confidence = 0.01, min_lift = 3, min_length = 2, max_length = 5)
results = list(sets)

# %% [markdown]
# # Displaying Result Of Eclat Model

# %%
results
# Out:
# [RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'mushroom cream sauce'}), confidence=0.0722689075630252, lift=3.7908326967150496), OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'pasta'}), confidence=0.07394957983193277, lift=4.700811850163794), OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %% [markdown]
# # Displaying Results In Dataframe

# %%
def inspect(results) :
    productSet = [result[0] for result in results]
    supports   = [result[1] for result in results]
    return list(zip(productSet, supports))

setsDataframe = pd.DataFrame(inspect(results), columns=["Products", "Supports"])

# %%
setsDataframe
# Out:
#                                             Products  Supports
# 0                   (escalope, mushroom cream sauce)  0.005733
# 1                                  (pasta, escalope)  0.005866
# 2                       (ground beef, herb & pepper)  0.015998
# 3                        (tomato sauce, ground beef)  0.005333
# 4                     (whole wheat pasta, olive oil)  0.007999
# 5                                    (shrimp, pasta)  0.005066
# 6             (shrimp, chocolate, frozen vegetables)  0.005333
# 7              (spaghetti, cooking oil, ground beef)  0.004799
# 8              (escalope, mushroom cream sauce, nan)  0.005733
# 9                             (pasta, escalope, nan)  0.005866
# 10       (spaghetti, frozen vegetables, ground beef)  0.008666
# 11              (frozen vegetables, olive oil, milk)  0.004799
# 12        (shrimp, mineral water, frozen vegetables)  0.007199
# 13         (spaghetti, frozen vegetables, olive oil)  0.005733
# ...

# %% [markdown]
# # Displaying In Sorted Order Of Supports

# %%
setsDataframe.nlargest(n = ,columns="Supports")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c706d65909df> in <module>
# ----> 1 setsDataframe.nlargest(columns="Supports")
#
# TypeError: nlargest() missing 1 required positional argument: 'n'
